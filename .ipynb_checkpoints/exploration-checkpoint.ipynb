# %% [markdown]
# # Data Exploration: Archetypometrics
#
# Following the methodology of the original paper:
# - **Matrix A:** 464 traits x 2000 characters.
# - **Normalization:** Scores are normalized to range [-0.5, 0.5].
# - **SVD:** Performed without centering the data.

# %%
import pandas as pd
import os
import numpy as np

# Define the path to the data
data_dir = 'data/plain/current/2000/'

# Load metadata
stories_df = pd.read_csv(os.path.join(data_dir, 'data_stories.tsv'), sep='\t')
characters_df = pd.read_csv(os.path.join(data_dir, 'data_characters.tsv'), sep='\t')
traits_df = pd.read_csv(os.path.join(data_dir, 'data_traits.tsv'), sep='\t')

# Load the character-trait matrix A
A_raw = np.loadtxt(os.path.join(data_dir, 'data_raw_A.txt'))
A = A_raw.T 

print(f"Matrix A shape (Traits x Characters): {A.shape}")
print(f"Value range: [{np.min(A)}, {np.max(A)}]")
# Out:
# Matrix A shape (Traits x Characters): (2000, 464)
# Value range: [-0.489, 0.498]

# %%
stories_df
# Out:
#        1            (500) Days of Summer My Little Pony: Friendship Is Magic  \
# 0      2      10 Things I Hate About You                                NCIS
# 1      3                         30 Rock                        Wynonna Earp
# 2      4                          8 Mile                    The Walking Dead
# 3      5       A Nightmare on Elm Street                        White Collar
# 4      6  A Series of Unfortunate Events                        Breaking Bad
# ..   ...                             ...                                 ...
# 335  337                           X-Men                  The Queen's Gambit
# 336  338                   Yellowjackets                   Lord of the Rings
# 337  339                     Yellowstone           Marvel Cinematic Universe
# 338  340                             You                              Naruto
# 339  341                      Zombieland                        Ghostbusters
#
#     https://compstorylab.org/archetypometrics/cards/My-Little-Pony-Friendship-Is-Magic-2000-464-341.pdf
# 0    https://compstorylab.org/archetypometrics/card...
# 1    https://compstorylab.org/archetypometrics/card...
# 2    https://compstorylab.org/archetypometrics/card...
# 3    https://compstorylab.org/archetypometrics/card...
# 4    https://compstorylab.org/archetypometrics/card...
# ..                                                 ...
# 335  https://compstorylab.org/archetypometrics/card...
# 336  https://compstorylab.org/archetypometrics/card...
# 337  https://compstorylab.org/archetypometrics/card...
# 338  https://compstorylab.org/archetypometrics/card...
# 339  https://compstorylab.org/archetypometrics/card...
#
# [340 rows x 4 columns]

# %%
characters_df
# Out:
#       index         character character in latex  \
# 0         1         Applejack          Applejack
# 1         2  Twilight Sparkle   Twilight Sparkle
# 2         3            Rarity             Rarity
# 3         4        Pinkie Pie         Pinkie Pie
# 4         5             Spike              Spike
# ...     ...               ...                ...
# 1995   1996     Peter Venkman      Peter Venkman
# 1996   1997        Ray Stantz         Ray Stantz
# 1997   1998     Egon Spengler      Egon Spengler
# 1998   1999      Dana Barrett       Dana Barrett
# 1999   2000       Louis Tully        Louis Tully
#
#                                         character/story  \
# 0         Applejack/My Little Pony: Friendship Is Magic
# 1     Twilight Sparkle/My Little Pony: Friendship Is...
# 2            Rarity/My Little Pony: Friendship Is Magic
# 3        Pinkie Pie/My Little Pony: Friendship Is Magic
# 4             Spike/My Little Pony: Friendship Is Magic
# ...                                                 ...
# 1995                         Peter Venkman/Ghostbusters
# 1996                            Ray Stantz/Ghostbusters
# 1997                         Egon Spengler/Ghostbusters
# 1998                          Dana Barrett/Ghostbusters
# 1999                           Louis Tully/Ghostbusters
#
#                                character/story in latex  \
# 0         Applejack/My Little Pony: Friendship Is Magic
# 1     Twilight Sparkle/My Little Pony: Friendship Is...
# 2            Rarity/My Little Pony: Friendship Is Magic
# 3        Pinkie Pie/My Little Pony: Friendship Is Magic
# 4             Spike/My Little Pony: Friendship Is Magic
# ...                                                 ...
# 1995                         Peter Venkman/Ghostbusters
# 1996                            Ray Stantz/Ghostbusters
# 1997                         Egon Spengler/Ghostbusters
# 1998                          Dana Barrett/Ghostbusters
# 1999                           Louis Tully/Ghostbusters
#
#                                                card url  original_moral_score  \
# 0     https://compstorylab.org/archetypometrics/card...               -0.3830
# 1     https://compstorylab.org/archetypometrics/card...               -0.3360
# 2     https://compstorylab.org/archetypometrics/card...               -0.2375
# 3     https://compstorylab.org/archetypometrics/card...               -0.4105
# 4     https://compstorylab.org/archetypometrics/card...               -0.2965
# ...                                                 ...                   ...
# 1995  https://compstorylab.org/archetypometrics/card...               -0.2205
# 1996  https://compstorylab.org/archetypometrics/card...               -0.3800
# 1997  https://compstorylab.org/archetypometrics/card...               -0.3500
# 1998  https://compstorylab.org/archetypometrics/card...               -0.1835
# 1999  https://compstorylab.org/archetypometrics/card...               -0.2320
#
#       custom_axis_score
# 0              0.515209
# 1              0.473568
# 2              0.282100
# 3              0.559708
# 4              0.299246
# ...                 ...
# 1995          -0.044907
# 1996           0.446624
# 1997           0.412331
# 1998           0.162891
# 1999           0.343745
#
# [2000 rows x 8 columns]

# %%
traits_df
# Out:
#      index                  differential          flipped differential  \
# 0        1            playful :: serious            serious :: playful
# 1        2                   shy :: bold                   bold :: shy
# 2        3           cheery :: sorrowful           sorrowful :: cheery
# 3        4         masculine :: feminine         feminine :: masculine
# 4        5           charming :: awkward           awkward :: charming
# ..     ...                           ...                           ...
# 459    460                 manic :: mild                 mild :: manic
# 460    461  old-fashioned :: progressive  progressive :: old-fashioned
# 461    462             gross :: hygienic             hygienic :: gross
# 462    463            stable :: unstable            unstable :: stable
# 463    464   overthinker :: underthinker   underthinker :: overthinker
#
#          left pole    right pole  \
# 0          playful       serious
# 1              shy          bold
# 2           cheery     sorrowful
# 3        masculine      feminine
# 4         charming       awkward
# ..             ...           ...
# 459          manic          mild
# 460  old-fashioned   progressive
# 461          gross      hygienic
# 462         stable      unstable
# 463    overthinker  underthinker
#
#                                               card url
# 0    https://compstorylab.org/archetypometrics/card...
# 1    https://compstorylab.org/archetypometrics/card...
# 2    https://compstorylab.org/archetypometrics/card...
# 3    https://compstorylab.org/archetypometrics/card...
# 4    https://compstorylab.org/archetypometrics/card...
# ..                                                 ...
# 459  https://compstorylab.org/archetypometrics/card...
# 460  https://compstorylab.org/archetypometrics/card...
# 461  https://compstorylab.org/archetypometrics/card...
# 462  https://compstorylab.org/archetypometrics/card...
# 463  https://compstorylab.org/archetypometrics/card...
#
# [464 rows x 6 columns]

# %% [markdown]
# ## Moral Vector Projection (Original 4 Traits)
# Using Honorable, Loyal, Heroic, and Forgiving.

# %%
# Ensure A is oriented as (Characters x Traits)
A_ct = A.T if A.shape[0] == 464 else A

w = np.zeros(464)
w[13] = 1.0 # honorable :: cunning
w[27] = 1.0 # loyal :: traitorous
w[38] = 1.0 # heroic :: villainous
w[24] = 1.0 # forgiving :: vengeful
w /= np.linalg.norm(w)

characters_df['original_moral_score'] = A_ct @ w

print("--- Top 10 Most 'Heroic' ---")
display(characters_df.sort_values('original_moral_score').head(10)[['character', 'character/story', 'original_moral_score']])
# Out:
# --- Top 10 Most 'Heroic' ---
#                   character                              character/story  \
# 927                      Ed                              Ed/Cowboy Bebop
# 506           Luna Lovegood                   Luna Lovegood/Harry Potter
# 441   SpongeBob SquarePants  SpongeBob SquarePants/SpongeBob SquarePants
# 1730         Lilah MacManus                  Lilah MacManus/Ctrl+Alt+Del
# 1706           Keeley Jones                       Keeley Jones/Ted Lasso
# 515          George Weasley                  George Weasley/Harry Potter
# 1134                  Viola                          Viola/Twelfth Night
# 30          Elizabeth Burke                 Elizabeth Burke/White Collar
# 1362                   Aang              Aang/Avatar: The Last Airbender
# 1838            Sasha Braus                  Sasha Braus/Attack on Titan
#
#       original_moral_score
# 927                -0.5215
# 506                -0.5065
# 441                -0.5050
# 1730               -0.5040
# 1706               -0.5015
# 515                -0.4975
# 1134               -0.4965
# 30                 -0.4935
# 1362               -0.4905
# 1838               -0.4885

# %% [markdown]
# ## Flexible Trait Exploration (Up to 6 Traits)
# Pick your traits and directions (-1 for Left Pole, +1 for Right Pole).

# %%
# CUSTOMIZE YOUR AXIS HERE
custom_traits = {
    38: -1, # heroic :: villainous (Target: Heroic)
    83: +1, # cruel :: kind (Target: Kind)
    78: +1, # selfish :: altruistic (Target: Altruistic)
    80: -1, # angelic :: demonic (Target: Angelic)
    13: -1, # honorable :: cunning (Target: Honorable)
    63: +1  # debased :: pure (Target: Pure)
}

w_custom = np.zeros(464)
print("Traits selected:")
for idx, direction in custom_traits.items():
    row = traits_df.iloc[idx]
    target = row['left pole'] if direction == -1 else row['right pole']
    print(f"- {row['differential']} (Point towards: {target})")
    w_custom[idx] = direction

w_custom /= np.linalg.norm(w_custom)
characters_df['custom_axis_score'] = A_ct @ w_custom

print("\n--- Top 10 Characters Aligned with Custom Axis ---")
display(characters_df.sort_values('custom_axis_score', ascending=False).head(10)[['character', 'character/story', 'custom_axis_score']])
# Out:
# Traits selected:
# - heroic :: villainous (Point towards: heroic)
# - cruel :: kind (Point towards: kind)
# - selfish :: altruistic (Point towards: altruistic)
# - angelic :: demonic (Point towards: angelic)
# - cunning :: honorable (Point towards: cunning)
# - debased :: pure (Point towards: pure)
#
# --- Top 10 Characters Aligned with Custom Axis ---
#            character                                  character/story  \
# 1708    Sam Obisanya                           Sam Obisanya/Ted Lasso
# 1140  Alphonse Elric  Alphonse Elric/Fullmetal Alchemist: Brotherhood
# 632    Mayuri Shiina                        Mayuri Shiina/Steins;Gate
# 969             Olaf                                      Olaf/Frozen
# 1362            Aang                  Aang/Avatar: The Last Airbender
# 1511   Kimmy Schmidt          Kimmy Schmidt/Unbreakable Kimmy Schmidt
# 506    Luna Lovegood                       Luna Lovegood/Harry Potter
# 1969  Samwise Gamgee                 Samwise Gamgee/Lord of the Rings
# 1036    Forrest Gump                        Forrest Gump/Forrest Gump
# 201         Pop Tate                               Pop Tate/Riverdale
#
#       custom_axis_score
# 1708           0.760975
# 1140           0.754851
# 632            0.729540
# 969            0.725457
# 1362           0.719742
# 1511           0.718925
# 506            0.716476
# 1969           0.694839
# 1036           0.693614
# 201            0.692389

# %% [markdown]
# ## SVD Analysis

# %%
U, S, Vt = np.linalg.svd(A, full_matrices=False)
print(f"Top 5 Singular Values: {S[:5]}")

# Check alignment with PC1
alignment = np.dot(Vt[0], w_custom)
print(f"Alignment of Custom Axis with PC1: {alignment:.4f}")
# Out:
# Top 5 Singular Values: [99.6627041  91.08522769 77.02479478 50.38811855 45.66893989]
# Alignment of Custom Axis with PC1: 0.0611
